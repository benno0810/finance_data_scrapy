# %%
import requests
import time
import pymongo

# %%
class DB():
    def __init__(self,db_type='MongoDB',db_address='mongodb://localhost:27017/',db_name='db_test',table_name='col_test'):
        self.db_address=db_address
        self.db_type=db_type
        self.db_name=db_name
        self.table_name=table_name

    def connect(self):
        pass

    def insert_one(self):
        pass

    def delete_one(self):
        pass

    def test_connection(self):
        pass
class ProxyPool_DB(DB):
    def __init__(self,db_type='MongoDB',db_address='mongodb://localhost:27017/',db_name='proxy_pool',table_name='proxy_col'):
        super().__init__(db_type,db_address,db_name,table_name)
        self.client = pymongo.MongoClient(self.db_address)
        self.db=self.client[self.db_name]
        col=self.db[self.table_name]
        collist=self.db.list_collection_names()
        if self.table_name in collist:
            print('集合已存在')
        else:               
            line={
                'ip_address':'127.0.0.1:30300',
                'expires_time': time.time()
            }
            x=col.insert_one(line)
            print(x)
    

    def test_connection(self):        
        return True
                

    def insert_one(self,line:dict):
        super().insert_one()
        if self.test_connection() and line.get('ip_address'):
            if not line.get('expires_time'):
                #若没有过期时间戳则设置过期时间戳为180秒+
                line['expires_time']=time.time()+180
            col=self.db[self.table_name]
            x=col.insert_one(line)
            print(x)

    def delete_many(self,myquery:dict):
        col=self.db[self.table_name]
        x = col.delete_many(myquery)
        print(x.deleted_count, "个文档已删除")


    def delete_one(self,myquery:dict):
        super().delete_one()
        
db_test = ProxyPool_DB()
line_test={
    'ip_address':'127.0.0.1:30031',
    'expires_time':time.time()-100
    }
#db_test.insert_one(line_test)

myquery={
    'ip_address':'127.0.0.1:30031'
}
db_test.delete_many(myquery)

# %%
for i in range(9):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %% [markdown]
# counter=0
# url='https://xueqiu.com/statuses/search.json?sort=time&source=all&q=%E6%B2%AA%E6%B7%B1300&count=10&page=1'
# session = requests.session()
#
# cookie="device_id=24700f9f1986800ab4fcc880530dd0ed; xq_a_token=1132205e8c57eb587b26526804cff9f3b6bf6799; xqat=1132205e8c57eb587b26526804cff9f3b6bf6799; xq_r_token=81b9c911ea3907729d8f8e9f60d9f5251227c551; xq_id_token=eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.eyJ1aWQiOi0xLCJpc3MiOiJ1YyIsImV4cCI6MTYwOTEyMzA1NywiY3RtIjoxNjA3MzE3NDU5NDY3LCJjaWQiOiJkOWQwbjRBWnVwIn0.L7TxtA3sgcvVmvtgYqHWgz7aSdB99tnXMslLjxBASL65AAefrdoge6WNA4aSMw3ljjoX9egg09f_TDwYRpAnSntVtVkyq4gGtToXR3SjdeWGNfZ5a4JC8HCK97NIFns7lHgUrQp5aJRTkXLNZPM1G1eqHh_T6btZTS4bXzboK0HUUC60iPW20YBpEK7UPq0Bi59IUFRFd99GWVxEqvmPerQK3BQLNW6MG0Mp8uHgWd7AH0pxEOxc4q0H9fROqrD4o9e_1saFnmijkGe-WPglmTewx9D0ckVJqsb5QMDgdV6UhABi3ZKwKCcXxu3fUT0CpXuDi9P6vMqCJ9KzJhOvQQ; u=361607317519382; Hm_lvt_1db88642e346389874251b5a1eded6e3=1606730322,1606981226,1607072124,1607317521; Hm_lpvt_1db88642e346389874251b5a1eded6e3=1607319693"
# session.headers = {
#     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36",
#     #"Host": "xueqiu.com",
#     #"Referer": "https://xueqiu.com/",
#     #"Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
#     #'Connection': 'keep-alive',
#     #'Cookie': cookie,  # 直接插入了cookie，试一试
#
#     }
#
# '''
# while True:
#     #print(counter)
#     counter=counter+1
#     html=session.get(url,timeout=5)
#     if html.text and counter%20==0:
#         print(counter)
#         print(html.status_code)
#         with open('{}.txt'.format(counter) , 'w', encoding='utf-8') as f:
#             f.write(html.text)
#
#     if counter>200:break
#
#
# '''
# while True:
#     #print(counter)
#     counter=counter+1
#     html=session.get(url,timeout=5)
#     if html.text:
#         print(html.text[:20])
#         if html.status_code==400:
#
#             print(html.text)
#             time.sleep(5)
#             html=session.get(url,timeout=5)
#             print(html.text,'\n')
#
#
#     if counter>200:break
